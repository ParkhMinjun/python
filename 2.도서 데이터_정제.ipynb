# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkhMinjun/python/blob/main/2.%EB%8F%84%EC%84%9C%20%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%95%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #불필요한 데이터 삭제

# %%
import pandas as pd
ns_df= pd.read_csv('청주시립도서관 장서 대출목록 (2024년 06월).csv',low_memory=False)
ns_df.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN    0  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27

# %% [markdown]
# ## 열 삭제하기

# %%
print(ns_df.columns)
# Out:
# Index(['번호', '도서명', '저자', '출판사', '발행년도', 'ISBN', '세트 ISBN', '부가기호', '권',
#        '주제분류번호', '도서권수', '대출건수', '등록일자'],
#       dtype='object')

# %%
print(ns_df.columns[0])
# Out:
# 번호

# %%
selected_columns = ns_df.columns != '부가기호'  #!= 비교연산자 부가기호가 아닌것은 True 부가기호는 False로 반
ns_book = ns_df.loc[:, selected_columns]      #loc 메서드 슬라이싱 사용
ns_book.head()                     #열 중간의 부가기호 삭
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN  NaN    843     1     0  2024-06-27

# %%
# doc()메서드 데이터프레임 행,열 삭제
ns_book = ns_df.drop(['부가기호'], axis=1)  #axis 기본값 0은 행 1은 열지정 삭제
ns_book.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN  NaN    843     1     0  2024-06-27

# %%
ns_book.drop('주제분류번호', axis=1, inplace=True) #inplace 매개변수가 True면 현재 선택한 데이터프레임 바로 수정
ns_book.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN    권  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN  NaN     1     0  2024-06-27
# 1  2007  9780261102361      NaN  NaN     1     0  2024-06-27
# 2  1991  9780261102378      NaN  NaN     1     0  2024-06-27
# 3  2020  9780261103344      NaN  NaN     1     0  2024-06-27
# 4  2020  9780261103573      NaN  NaN     1     0  2024-06-27

# %%
ns_book = ns_df.dropna(axis=1)  #dropna()는 nan이 하나이상 포함된 행,열 삭제 axis=1열 삭제
ns_book.head()
# Out:
#    번호                           도서명           ISBN  도서권수  대출건수        등록일자
# 0   1        (The)Lord of the Rings  9780261102354     1     0  2024-06-27
# 1   2              (The) Two Towers  9780261102361     1     0  2024-06-27
# 2   3      (The) Return of the King  9780261102378     1     0  2024-06-27
# 3   4                   (The)Hobbit  9780261103344     1     0  2024-06-27
# 4   5  (The) Fellowship of the ring  9780261103573     1     0  2024-06-27

# %%
ns_book = ns_df.dropna(axis=1, how='all') #how=all 모든값이 nan인 행,열 삭제
ns_book.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN    0  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27

# %% [markdown]
# ##행 삭제하기

# %%
ns_book2 = ns_book.drop([0,1])  #2개의 행 삭제
ns_book2.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
# 5   6               (The)Two towers   by J.R.R Tolkien      HarperCollins
# 6   7      (The) Return of the king   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27
# 5  2020  9780261103580      NaN    0  NaN    843     1     0  2024-06-27
# 6  2020  9780261103597      NaN    0  NaN    843     1     0  2024-06-27

# %%
ns_book2 = ns_book[2:]  # [] : 슬라이싱 사용
ns_book2.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
# 5   6               (The)Two towers   by J.R.R Tolkien      HarperCollins
# 6   7      (The) Return of the king   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27
# 5  2020  9780261103580      NaN    0  NaN    843     1     0  2024-06-27
# 6  2020  9780261103597      NaN    0  NaN    843     1     0  2024-06-27

# %%
ns_book2 = ns_book[0:2]  #0과 1 선택  #loc() 에 슬라이싱은 마지막 인덱스 포함하지만 []파이썬 연산자는 마지막 인덱스 포함 안함
ns_book2.head()
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  9780261102361      NaN    0  NaN    843     1     0  2024-06-27

# %%
selected_rows = ns_df['출판사'] == '한빛미디어' # 출판사가 한빛미디어인 행만 True인 불리언 배열 생성
ns_book2 = ns_book[selected_rows]
ns_book2.head()
# Out:
#         번호                                                도서명  \
# 1895  1896  엑셀 데이터 분석 바이블 = Excel bible : 실무에 최적화된 엑셀 사용서:...
# 2436  2437                    (처음 시작하는 개발자를 위한)나의 첫 안드로이드 =
# 2779  2780     (디자인 1등 유튜버 존코바의)클릭을 유도하는 유튜브 디자인 with 포토샵 =
# 3594  3595               데이터 스토리 =  : 데이터를 설득력 있는 이야기로 바꾸는 방법
# 3648  3649  머신러닝을 활용한 웹 최적화 =  : A/B 테스트, 메타휴리스틱, 슬롯머신 알고리...
#
#                       저자    출판사  발행년도           ISBN  세트 ISBN 부가기호    권  \
# 1895              최준선 지음  한빛미디어  2021  9791162244258      NaN    1  NaN
# 2436              한동호 지음  한빛미디어  2018  9791162240960      NaN    9  NaN
# 2779         존코바(이요한) 지음  한빛미디어  2021  9791162244708      NaN    1  NaN
# 3594  낸시 두아르테 지음  권혜정 옮김  한빛미디어  2021  9791162244296      NaN    9  NaN
# 3648  이쓰카 슈헤이 지음  김연수 옮김  한빛미디어  2021  9791162244357      NaN    9  NaN
#
#       주제분류번호  도서권수  대출건수        등록일자
# 1895  005.53     1     1  2021-11-23
# 2436  005.58     1     2  2021-10-28
# 2779  004.76     1     1  2021-10-14
# 3594  005.76     1     8  2021-08-03
# 3648  004.73     1     2  2021-08-03

# %%
ns_book2 = ns_book.loc[selected_rows]
ns_book2.head()
# Out:
#         번호                                                도서명  \
# 1895  1896  엑셀 데이터 분석 바이블 = Excel bible : 실무에 최적화된 엑셀 사용서:...
# 2436  2437                    (처음 시작하는 개발자를 위한)나의 첫 안드로이드 =
# 2779  2780     (디자인 1등 유튜버 존코바의)클릭을 유도하는 유튜브 디자인 with 포토샵 =
# 3594  3595               데이터 스토리 =  : 데이터를 설득력 있는 이야기로 바꾸는 방법
# 3648  3649  머신러닝을 활용한 웹 최적화 =  : A/B 테스트, 메타휴리스틱, 슬롯머신 알고리...
#
#                       저자    출판사  발행년도           ISBN  세트 ISBN 부가기호    권  \
# 1895              최준선 지음  한빛미디어  2021  9791162244258      NaN    1  NaN
# 2436              한동호 지음  한빛미디어  2018  9791162240960      NaN    9  NaN
# 2779         존코바(이요한) 지음  한빛미디어  2021  9791162244708      NaN    1  NaN
# 3594  낸시 두아르테 지음  권혜정 옮김  한빛미디어  2021  9791162244296      NaN    9  NaN
# 3648  이쓰카 슈헤이 지음  김연수 옮김  한빛미디어  2021  9791162244357      NaN    9  NaN
#
#       주제분류번호  도서권수  대출건수        등록일자
# 1895  005.53     1     1  2021-11-23
# 2436  005.58     1     2  2021-10-28
# 2779  004.76     1     1  2021-10-14
# 3594  005.76     1     8  2021-08-03
# 3648  004.73     1     2  2021-08-03

# %%
ns_book2 = ns_book[ns_book['대출건수'] > 10000] #연산자 바로 삽입
ns_book2.head()
# Out:
#           번호                       도서명           저자    출판사  발행년도  \
# 69174  69175                작은집 인테리어 =   [삼성 편집부 편]  삼성출판사  2009
# 85707  85708         土地  =  : 박경리 대하소설        박경리 저   나남출판  2005
# 86387  86388  아프리카행 특급열차 =  : 이윤아 장편소설        이윤아 저   영상노트  2006
# 88913  88914                내 이름은 오빠 =  아이하라 히로유키 글   밝은미래  2009
# 90332  90333    (사진과 그림으로 보는) 한국사 편지 =        박은봉 글   웅진닷컴  2002
#
#                 ISBN       세트 ISBN 부가기호    권 주제분류번호  도서권수   대출건수        등록일자
# 69174  9788915067646           NaN  NaN  NaN  619.5     1  16503  2016-12-08
# 85707  9788930007016  9.788930e+12  NaN   12  813.6     1  29381  2014-11-28
# 86387  9788956516714           NaN  NaN  NaN  813.6     1  25445  2014-10-21
# 88913  9788992693318           NaN  NaN  NaN  833.8     1  51676  2014-06-01
# 90332  9788901039121  9.788901e+12  NaN    2    911     1  71975  2014-03-05

# %% [markdown]
# ## 중복된 행 찾기

# %%
sum(ns_book.duplicated()) #duplicated() 중복된 행 주 처음 행을 제외한 나머지 행 True로 반환 # 파이썬 sum함수는 True를 1로 인식
# Out:
# 0

# %%
sum(ns_book.duplicated(subset=['도서명','저자','ISBN'])) #subset 매개변수로 기준 열 지정
# Out:
# 16727

# %%
dup_rows = ns_book.duplicated(subset=['도서명','저자','ISBN'], keep=False) #keep=False 중복된 모든 행 True로 표
ns_book3 = ns_book[dup_rows]
ns_book3.head()
# Out:
#       번호                                                도서명        저자    출판사  \
# 229  230                                지렁이의 코딱지 : 끝말잇기 대모험  지승희 글·그림   노란상상
# 299  300  동화로 만나는 프랑스자수 = Surock's atelier : 수록의 프랑스자수 아틀리에    박성희 지음     티나
# 306  307  처음 하는 재봉틀 A to Z  = My First Sewing Machine : ...    송효은 지음  즐거운상상
# 422  423                                지렁이의 코딱지 : 끝말잇기 대모험  지승희 글·그림   노란상상
# 984  985                     아프니까 청춘이다 : 인생 앞에 홀로 선 젊은 그대에게    김난도 지음  쌤앤파커스
#
#      발행년도           ISBN  세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수        등록일자
# 229  2024  9791193074350      NaN    7  NaN   808.9     1     1  2024-06-26
# 299  2017  9791195765034      NaN    1  NaN   636.5     1     0  2024-06-26
# 306  2011  9788992109765      NaN    1  NaN  592.21     1     0  2024-06-26
# 422  2024  9791193074350      NaN    7  NaN   808.9     1     1  2024-06-16
# 984  2010  9788965700036      NaN    0  NaN   199.1     1     0  2024-06-09

# %%
count_df = ns_book[['도서명','저자','ISBN','권','대출건수']]

# %%
loan_count = count_df.groupby(by=['도서명','저자','ISBN','권'], dropna=False).sum() # dropna nan이 있는 행도 포함 #sum으로 대출건수 합
loan_count.head()
# Out:
#                                                                               대출건수
# 도서명                                        저자              ISBN          권
# "Quiet in the library" =                   Wendy Evans 글   9789766449544 18     73
# "Slowly, slowly, slowly," said the sloth = [by] Eric Carle 9780142408476 35     17
# "공부가 어려워? 대학이 부러워?" =                      정사모 엮음          9788979530827 NaN    19
# "나마스떼" 다시 만나자 인도야 =  : 겁 없는 10대들의 인도여행기    김준효 [외]지음       9788997653416 NaN    12
# "대한민국 코리아" 이름부터 바꾸자 =                      최낙성 지음          9788955860313 NaN     4

# %% [markdown]
# 원본데이터 업데이트하기

# %%
#중복된 행 빼고 고유한 행 추출
dup_rows = ns_book.duplicated(subset=['도서명','저자','ISBN','권']) # 중복된 행을 True로 표시
unique_rows = ~dup_rows #불리언 배열 반전시켜 고유한 행을 True로 표시
ns_book3 = ns_book[unique_rows].copy() #고유한 행만 선택 #copy 복사본 만듦 업데이트할때 항상 복사하는 것이 좋다.

# %%
sum(ns_book3.duplicated(subset=['도서명','저자','ISBN','권']))
# Out:
# 0

# %%
ns_book3.set_index(['도서명','저자','ISBN','권'], inplace=True) # 지정열 인덱스 설정
ns_book3.head()
# Out:
#                                                                   번호  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN   1
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN   2
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN   3
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN   4
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN   5
#
#                                                                                 출판사  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN      HarperCollins
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  HarperCollins(UK)
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  HarperCollins(UK)
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN      HarperCollins
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN      HarperCollins
#
#                                                                   발행년도  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN  2001
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  2007
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  1991
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN  2020
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN  2020
#
#                                                                   세트 ISBN  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN      NaN
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN      NaN
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN      NaN
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN      NaN
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN      NaN
#
#                                                                  부가기호 주제분류번호  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN    0    843
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN    0    843
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN    0    843
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN    0  843.5
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN    0    843
#
#                                                                   도서권수  대출건수  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN     1     0
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN     1     0
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN     1     0
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN     1     0
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN     1     0
#
#                                                                         등록일자
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN  2024-06-27
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  2024-06-27
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  2024-06-27
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN  2024-06-27
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN  2024-06-27

# %%
ns_book3.update(loan_count) # 업데이
ns_book3.head()
# Out:
#                                                                   번호  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN   1
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN   2
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN   3
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN   4
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN   5
#
#                                                                                 출판사  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN      HarperCollins
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  HarperCollins(UK)
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  HarperCollins(UK)
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN      HarperCollins
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN      HarperCollins
#
#                                                                   발행년도  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN  2001
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  2007
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  1991
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN  2020
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN  2020
#
#                                                                   세트 ISBN  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN      NaN
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN      NaN
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN      NaN
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN      NaN
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN      NaN
#
#                                                                  부가기호 주제분류번호  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN    0    843
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN    0    843
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN    0    843
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN    0  843.5
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN    0    843
#
#                                                                   도서권수  대출건수  \
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN     1     0
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN     1     0
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN     1     0
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN     1     0
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN     1     0
#
#                                                                         등록일자
# 도서명                          저자                ISBN          권
# (The)Lord of the Rings       by J.R.R Tolkien  9780261102354 NaN  2024-06-27
# (The) Two Towers             by J.R.R Tolkien  9780261102361 NaN  2024-06-27
# (The) Return of the King     by J.R.R Tolkien  9780261102378 NaN  2024-06-27
# (The)Hobbit                  by J.R.R. Tolkien 9780261103344 NaN  2024-06-27
# (The) Fellowship of the ring by J.R.R Tolkien  9780261103573 NaN  2024-06-27

# %%
ns_book4 = ns_book3.reset_index() # 인데스 열 해
ns_book4.head()
# Out:
#                             도서명                 저자           ISBN    권  번호  \
# 0        (The)Lord of the Rings   by J.R.R Tolkien  9780261102354  NaN   1
# 1              (The) Two Towers   by J.R.R Tolkien  9780261102361  NaN   2
# 2      (The) Return of the King   by J.R.R Tolkien  9780261102378  NaN   3
# 3                   (The)Hobbit  by J.R.R. Tolkien  9780261103344  NaN   4
# 4  (The) Fellowship of the ring   by J.R.R Tolkien  9780261103573  NaN   5
#
#                  출판사  발행년도  세트 ISBN 부가기호 주제분류번호  도서권수  대출건수        등록일자
# 0      HarperCollins  2001      NaN    0    843     1     0  2024-06-27
# 1  HarperCollins(UK)  2007      NaN    0    843     1     0  2024-06-27
# 2  HarperCollins(UK)  1991      NaN    0    843     1     0  2024-06-27
# 3      HarperCollins  2020      NaN    0  843.5     1     0  2024-06-27
# 4      HarperCollins  2020      NaN    0    843     1     0  2024-06-27

# %%
sum(ns_book['대출건수']>100) # 원본 데이터 대출건수
# Out:
# 5747

# %%
sum(ns_book4['대출건수']>100) #중복된 도서 합한 데이터 대출건수
# Out:
# 6239

# %%
ns_book4 = ns_book4[ns_book.columns] # 열 이름 전달 (순서대로 정렬)
ns_book4.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN    0  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27

# %%
ns_book4.to_csv('ns_book4.csv', index=False) # 데이터 저장

# %%
# 일괄 처리 함수
def data_cleaning(filename):
    """
    남산 도서관 장서 CSV 데이터 전처리 함수

    :param filename: CSV 파일이름
    """
    # 파일을 데이터프레임으로 읽습니다.
    ns_df = pd.read_csv(filename, low_memory=False)
    # NaN인 열을 삭제합니다.
    ns_book = ns_df.dropna(axis=1, how='all')

    # 대출건수를 합치기 위해 필요한 행만 추출하여 count_df 데이터프레임을 만듭니다.
    count_df = ns_book[['도서명','저자','ISBN','권','대출건수']]
    # 도서명, 저자, ISBN, 권을 기준으로 대출건수를 groupby합니다.
    loan_count = count_df.groupby(by=['도서명','저자','ISBN','권'], dropna=False).sum()
    # 원본 데이터프레임에서 중복된 행을 제외하고 고유한 행만 추출하여 복사합니다.
    dup_rows = ns_book.duplicated(subset=['도서명','저자','ISBN','권'])
    unique_rows = ~dup_rows
    ns_book3 = ns_book[unique_rows].copy()
    # 도서명, 저자, ISBN, 권을 인덱스로 설정합니다.
    ns_book3.set_index(['도서명','저자','ISBN','권'], inplace=True)
    # load_count에 저장된 누적 대출건수를 업데이트합니다.
    ns_book3.update(loan_count)

    # 인덱스를 재설정합니다.
    ns_book4 = ns_book3.reset_index()
    # 원본 데이터프레임의 열 순서로 변경합니다.
    ns_book4 = ns_book4[ns_book.columns]

    return ns_book4

# %%
new_ns_book4 = data_cleaning('청주시립도서관 장서 대출목록 (2024년 06월).csv')

ns_book4.equals(new_ns_book4)
# Out:
# True

# %% [markdown]
# # 잘못된 데이터 수정

# %% [markdown]
# ## 데이터 프레임 정보 요약

# %%
import pandas as pd
ns_book4= pd.read_csv('청주시립도서관 장서 대출목록 (2024년 06월).csv',low_memory=False)
ns_book4.head()
# Out:
#    번호                           도서명                 저자                출판사  \
# 0   1        (The)Lord of the Rings   by J.R.R Tolkien      HarperCollins
# 1   2              (The) Two Towers   by J.R.R Tolkien  HarperCollins(UK)
# 2   3      (The) Return of the King   by J.R.R Tolkien  HarperCollins(UK)
# 3   4                   (The)Hobbit  by J.R.R. Tolkien      HarperCollins
# 4   5  (The) Fellowship of the ring   by J.R.R Tolkien      HarperCollins
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  2001  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  2007  9780261102361      NaN    0  NaN    843     1     0  2024-06-27
# 2  1991  9780261102378      NaN    0  NaN    843     1     0  2024-06-27
# 3  2020  9780261103344      NaN    0  NaN  843.5     1     0  2024-06-27
# 4  2020  9780261103573      NaN    0  NaN    843     1     0  2024-06-27

# %%
#데이터프레임 정보 요악
ns_book4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211999 entries, 0 to 211998
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   번호       211999 non-null  int64
#  1   도서명      211999 non-null  object
#  2   저자       211933 non-null  object
#  3   출판사      203149 non-null  object
#  4   발행년도     209682 non-null  object
#  5   ISBN     211999 non-null  object
#  6   세트 ISBN  15857 non-null   float64
#  7   부가기호     37655 non-null   object
#  8   권        67437 non-null   object
#  9   주제분류번호   211837 non-null  object
#  10  도서권수     211999 non-null  int64
#  11  대출건수     211999 non-null  int64
#  12  등록일자     211999 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 21.0+ MB

# %%
ns_book4.info(memory_usage='deep') #정확한 메모리 샤용량 표시
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211999 entries, 0 to 211998
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   번호       211999 non-null  int64
#  1   도서명      211999 non-null  object
#  2   저자       211933 non-null  object
#  3   출판사      203149 non-null  object
#  4   발행년도     209682 non-null  object
#  5   ISBN     211999 non-null  object
#  6   세트 ISBN  15857 non-null   float64
#  7   부가기호     37655 non-null   object
#  8   권        67437 non-null   object
#  9   주제분류번호   211837 non-null  object
#  10  도서권수     211999 non-null  int64
#  11  대출건수     211999 non-null  int64
#  12  등록일자     211999 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 136.6 MB

# %% [markdown]
# ## 누락된 값 처리

# %%
ns_book4.isna().sum() #누락 값 확인
# Out:
# 번호              0
# 도서명             0
# 저자             66
# 출판사          8850
# 발행년도         2317
# ISBN            0
# 세트 ISBN    196142
# 부가기호       174344
# 권          144562
# 주제분류번호        162
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %%
ns_book4.notna().sum() #누락 되지 않은 값 확인
# Out:
# 번호         211999
# 도서명        211999
# 저자         211933
# 출판사        203149
# 발행년도       209682
# ISBN       211999
# 세트 ISBN     15857
# 부가기호        37655
# 권           67437
# 주제분류번호     211837
# 도서권수       211999
# 대출건수       211999
# 등록일자       211999
# dtype: int64

# %%
ns_book4.loc[0, '도서권수'] = None # 임의의 누락 값 생성
ns_book4['도서권수'].isna().sum()
# Out:
# 1

# %%
ns_book4.head(2)
#nan은 특별한 실수 값으로 저장하기 때문에 데이터 타입이 1->1.0으로 바뀌었음. int->float
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354      NaN    0  NaN    843   NaN     0  2024-06-27
# 1  9780261102361      NaN    0  NaN    843   1.0     0  2024-06-27

# %%
# 데이터 타입 지정 astype()메서드 , 딕셔너리 전달
ns_book4.loc[0, '도서권수'] = 1
ns_book4 = ns_book4.astype({'도서권수':'int32', '대출건수': 'int32'})
ns_book4.head(2)
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354      NaN    0  NaN    843     1     0  2024-06-27
# 1  9780261102361      NaN    0  NaN    843     1     0  2024-06-27

# %%
# 문자열 그래도 None표기
ns_book4.loc[0, '부가기호'] = None
ns_book4.head(2)
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN  세트 ISBN  부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354      NaN  None  NaN    843     1     0  2024-06-27
# 1  9780261102361      NaN     0  NaN    843     1     0  2024-06-27

# %%
import numpy as np

ns_book4.loc[0, '부가기호'] = np.nan # 넘파이 패키지 nan 생성
ns_book4.head(2)
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354      NaN  NaN  NaN    843     1     0  2024-06-27
# 1  9780261102361      NaN    0  NaN    843     1     0  2024-06-27

# %%
#loc() 사용 누락 값을 원하는 값으로 바꿀수 있다.
set_isbn_na_rows = ns_book4['세트 ISBN'].isna() #누락 값 찾아 불리언 배열로 반환
ns_book4.loc[set_isbn_na_rows, '세트 ISBN'] = '' #누락 값 빈 문자열로 바꿈

ns_book4['세트 ISBN'].isna().sum()
# Out:
# 0

# %%
#fillna() 매서드에 원하는 값 전달하면 NaN 대체
ns_book4.fillna('없음').isna().sum() #nan이 모두 없음의 문자열로 바
# Out:
# 번호         0
# 도서명        0
# 저자         0
# 출판사        0
# 발행년도       0
# ISBN       0
# 세트 ISBN    0
# 부가기호       0
# 권          0
# 주제분류번호     0
# 도서권수       0
# 대출건수       0
# 등록일자       0
# dtype: int64

# %%
ns_book4['부가기호'].fillna('없음').isna().sum() #특정 열 지정
# Out:
# 0

# %%
# 특정열 바꾸면서 전체 데이터프레임 반환은 딕셔너리 전달
ns_book4.fillna({'부가기호':'없음'}).isna().sum()
# Out:
# 번호              0
# 도서명             0
# 저자             66
# 출판사          8850
# 발행년도         2317
# ISBN            0
# 세트 ISBN         0
# 부가기호            0
# 권          144562
# 주제분류번호        162
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %%
#replace() 매서드는 nan은 물론 어떠한 값도 바꿀수 있다.
ns_book4.replace(np.nan, '없음').isna().sum() #(원래 값,새로운 값)
# Out:
# 번호         0
# 도서명        0
# 저자         0
# 출판사        0
# 발행년도       0
# ISBN       0
# 세트 ISBN    0
# 부가기호       0
# 권          0
# 주제분류번호     0
# 도서권수       0
# 대출건수       0
# 등록일자       0
# dtype: int64

# %%
ns_book4.replace([np.nan, '2001'], ['없음', '01']).head(2)  #리스트
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins    01
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN 세트 ISBN 부가기호   권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354           없음  없음    843     1     0  2024-06-27
# 1  9780261102361            0  없음    843     1     0  2024-06-27

# %%
ns_book4.replace({np.nan: '없음', '2001': '01'}).head(2) #딕셔너
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins    01
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN 세트 ISBN 부가기호   권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354           없음  없음    843     1     0  2024-06-27
# 1  9780261102361            0  없음    843     1     0  2024-06-27

# %%
ns_book4.replace({'부가기호': np.nan}, '없음').head(2) #열마다 다른 값을 바꿈
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins  2001
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354           없음  NaN    843     1     0  2024-06-27
# 1  9780261102361            0  NaN    843     1     0  2024-06-27

# %%
ns_book4.replace({'부가기호': {np.nan: '없음'}, '발행년도': {'2001': '01'}}).head(2)
# Out:
#    번호                     도서명                저자                출판사  발행년도  \
# 0   1  (The)Lord of the Rings  by J.R.R Tolkien      HarperCollins    01
# 1   2        (The) Two Towers  by J.R.R Tolkien  HarperCollins(UK)  2007
#
#             ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9780261102354           없음  NaN    843     1     0  2024-06-27
# 1  9780261102361            0  NaN    843     1     0  2024-06-27

# %% [markdown]
# ## 정규 표현식

# %%
ns_book4.replace({'발행년도': {'2021': '21'}})[100:102]
# Out:
#       번호                                   도서명      저자    출판사  발행년도  \
# 100  101                         (정브르의) 파충류 일기  정브르 지음  서울문화사  2019
# 101  102  (정브르의)아마존 일기 : 브르와 함께 떠나는 아마존 정글 탐험!  정브로 지음  서울문화사  2023
#
#               ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 100  9791164389919            7  NaN    497     1     1  2024-06-26
# 101  9791169237468            7  NaN    472     1     2  2024-06-26

# %%
# \d 숫자 표현 기호, 그룹으로 묶을때() 사용 \1 첫번째 그룹으로 사용
ns_book4.replace({'발행년도': {r'\d\d(\d\d)': r'\1'}}, regex=True)[100:102]
# Out:
#       번호                                   도서명      저자    출판사 발행년도  \
# 100  101                         (정브르의) 파충류 일기  정브르 지음  서울문화사   19
# 101  102  (정브르의)아마존 일기 : 브르와 함께 떠나는 아마존 정글 탐험!  정브로 지음  서울문화사   23
#
#               ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 100  9791164389919            7  NaN    497     1     1  2024-06-26
# 101  9791169237468            7  NaN    472     1     2  2024-06-26

# %%
# {} 개수 지정
ns_book4.replace({'발행년도': {r'\d{2}(\d{2})': r'\1'}}, regex=True)[100:102]
# Out:
#       번호                                   도서명      저자    출판사 발행년도  \
# 100  101                         (정브르의) 파충류 일기  정브르 지음  서울문화사   19
# 101  102  (정브르의)아마존 일기 : 브르와 함께 떠나는 아마존 정글 탐험!  정브로 지음  서울문화사   23
#
#               ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 100  9791164389919            7  NaN    497     1     1  2024-06-26
# 101  9791169237468            7  NaN    472     1     2  2024-06-26

# %%
# \s 공백문자 .는 문자 *는 0개이상 반복
ns_book4.replace({'도서명': {r'\(정브르의\)\s(.*)\s(.*)': r'\1\2'},
                  '발행년도': {r'\d{2}(\d{2})': r'\1'}}, regex=True)[100:102]
# Out:
#       번호                                   도서명      저자    출판사 발행년도  \
# 100  101                                 파충류일기  정브르 지음  서울문화사   19
# 101  102  (정브르의)아마존 일기 : 브르와 함께 떠나는 아마존 정글 탐험!  정브로 지음  서울문화사   23
#
#               ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 100  9791164389919            7  NaN    497     1     1  2024-06-26
# 101  9791169237468            7  NaN    472     1     2  2024-06-26

# %% [markdown]
# ## 잘못된 값 바꾸기

# %%
# 아래 코드는 오류 발생
# ns_book4.astype({'발행년도': 'int32'})
# 숫자가 아닌 다른 문자 있음.

# %%
ns_book4['발행년도'].str.contains('1988').sum() # 문자열 패턴 포함 여
# Out:
# 38

# %%
invalid_number = ns_book4['발행년도'].str.contains('\D', na=True) #\D 는 모든 문자에 대응하는 졍규표현 ,숫자가 아닌 문자 포함 행 찾기
print(invalid_number.sum()) #숫자 이외의 문자 들어간 행 개수 출력
ns_book4[invalid_number].head()
# Out:
# 2329
#         번호                                                도서명  \
# 4200  4201                                   ?????????????? =
# 5014  5015  (정말 못 쓰겠다 싶을 땐)9칸 글쓰기 =  : 9칸을 채우면 저절로 글이 나오는 ...
# 5084  5085    Stars twinkle and other questions about space =
# 8050  8051                                       빙하를 탐하다  =
# 9481  9482                                   자연이랑 동요 =  : 동요책
#
#                       저자     출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 4200         ???????????     NaN   NaN  9786167112671            9  NaN
# 5014  야마구치 다쿠로 지음 홍성민 옮김   e비즈북스  e비즈북  9791157831814            0  NaN
# 5084     by Carole Stott     NaN   NaN  9780753435298          NaN  NaN
# 8050            임경자 [지음]  해드림출판사   NaN  9791156344186            [  NaN
# 9481              하늘땅 작사      아람   NaN  9788966929856          NaN   81
#
#       주제분류번호  도서권수  대출건수        등록일자
# 4200  839.81     1     1  2021-06-27
# 5014     802     1     5  2021-05-25
# 5084     440     1     1  2021-05-23
# 8050   814.7     1     1  2021-01-22
# 9481     408     1     1  2020-11-19

# %%
ns_book5 = ns_book4.replace({'발행년도':r'.*(\d{4}).*'}, r'\1', regex=True)
ns_book5[invalid_number].head()
# Out:
#         번호                                                도서명  \
# 4200  4201                                   ?????????????? =
# 5014  5015  (정말 못 쓰겠다 싶을 땐)9칸 글쓰기 =  : 9칸을 채우면 저절로 글이 나오는 ...
# 5084  5085    Stars twinkle and other questions about space =
# 8050  8051                                       빙하를 탐하다  =
# 9481  9482                                   자연이랑 동요 =  : 동요책
#
#                       저자     출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 4200         ???????????     NaN   NaN  9786167112671            9  NaN
# 5014  야마구치 다쿠로 지음 홍성민 옮김   e비즈북스  e비즈북  9791157831814            0  NaN
# 5084     by Carole Stott     NaN   NaN  9780753435298          NaN  NaN
# 8050            임경자 [지음]  해드림출판사   NaN  9791156344186            [  NaN
# 9481              하늘땅 작사      아람   NaN  9788966929856          NaN   81
#
#       주제분류번호  도서권수  대출건수        등록일자
# 4200  839.81     1     1  2021-06-27
# 5014     802     1     5  2021-05-25
# 5084     440     1     1  2021-05-23
# 8050   814.7     1     1  2021-01-22
# 9481     408     1     1  2020-11-19

# %%
unkown_year = ns_book5['발행년도'].str.contains('\D', na=True) # 숫자이외의 문자 들어간 행 확인
print(unkown_year.sum())
ns_book5[unkown_year].head()
# Out:
# 2319
#         번호                                                도서명  \
# 4200  4201                                   ?????????????? =
# 5014  5015  (정말 못 쓰겠다 싶을 땐)9칸 글쓰기 =  : 9칸을 채우면 저절로 글이 나오는 ...
# 5084  5085    Stars twinkle and other questions about space =
# 8050  8051                                       빙하를 탐하다  =
# 9481  9482                                   자연이랑 동요 =  : 동요책
#
#                       저자     출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 4200         ???????????     NaN   NaN  9786167112671            9  NaN
# 5014  야마구치 다쿠로 지음 홍성민 옮김   e비즈북스  e비즈북  9791157831814            0  NaN
# 5084     by Carole Stott     NaN   NaN  9780753435298          NaN  NaN
# 8050            임경자 [지음]  해드림출판사   NaN  9791156344186            [  NaN
# 9481              하늘땅 작사      아람   NaN  9788966929856          NaN   81
#
#       주제분류번호  도서권수  대출건수        등록일자
# 4200  839.81     1     1  2021-06-27
# 5014     802     1     5  2021-05-25
# 5084     440     1     1  2021-05-23
# 8050   814.7     1     1  2021-01-22
# 9481     408     1     1  2020-11-19

# %%
ns_book5.loc[unkown_year, '발행년도'] = '-1' #임의의 값 바
ns_book5 = ns_book5.astype({'발행년도': 'int32'})

# %%
ns_book5['발행년도'].gt(2025).sum() #연도가 2025년보다 큰 값 확인 ,gt() 전달 값보다 큰 값 찾기
# Out:
# 2

# %%
dangun_year = ns_book5['발행년도'].gt(2025)
print(dangun_year.sum())
ns_book5[dangun_year].head(2)
# Out:
# 2
#           번호                                    도서명                     저자  \
# 5246    5247  애린 왕자 =  : 갱상도(Gyeongsang-do dialect)  앙투안 드 생텍쥐페리 지음 최현애 옮김
# 29447  29448                                백점빵 =                 배욱찬 글·그림
#
#          출판사  발행년도           ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수  \
# 5246      이팝  2121  9791197182204            0  NaN    863     1     4
# 29447  책과콩나무  2104  9788994077697            7  NaN  813.8     1    30
#
#              등록일자
# 5246   2021-05-04
# 29447  2018-11-07

# %%
ns_book5.loc[dangun_year, '발행년도'] = -1 # 임의의 값으로 바꿈

# %%
old_books = ns_book5['발행년도'].gt(0) & ns_book5['발행년도'].lt(1900) # 0보다 크고 1900보다 작은
ns_book5[old_books]
# Out:
#           번호                                                도서명      저자  \
# 166      167                                  이상한 기차  : 한아름 그림책  한아름 지음
# 35727  35728  (홍익희의)유대인 경제사  = Jewish economic history : the...  홍익희 지음
#
#          출판사  발행년도           ISBN          세트 ISBN 부가기호    권     주제분류번호  도서권수  \
# 166       창비    20  9788936455262                     7  NaN      813.8     1
# 35727  한즈미디어    16  9791160070309  9788959758616.0    1    6  320.91863     1
#
#        대출건수        등록일자
# 166       2  2024-06-26
# 35727     5  2018-05-15

# %%
ns_book5.loc[old_books, '발행년도'] = -1

# %%
ns_book5['발행년도'].eq(-1).sum() # 총 2323권이 잘못되거나 누락된 값
# Out:
# 2323

# %% [markdown]
# ## 누락된 정보 채우기

# %%
na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
          | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
print(na_rows.sum())
ns_book5[na_rows].head(2)
# Out:
# 11048
#         번호                      도서명                 저자  출판사  발행년도  \
# 166    167        이상한 기차  : 한아름 그림책             한아름 지음   창비    -1
# 1121  1122  Khoai Tay lai may bay =  l?i: Mai T?? Ha?m  NaN  2013
#
#                ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 166   9788936455262            7  NaN  813.8     1     2  2024-06-26
# 1121  8935036676290            8  NaN    823     1     1  2022-04-18

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 도서명 가져오는 함수
def get_book_title(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    # 클래스 이름이 'gd_name'인 a 태그의 텍스트를 가져옵니다.
    title = soup.find('a', attrs={'class':'gd_name'}) \
            .get_text()
    return title

# %%
get_book_title(9791191266054)
# Out:
# '골목의 시간을 그리다'

# %%
# 저자,출판사,발행 연도 추출 함수
import re # 정규표현식 지원

def get_book_info(row):
    title = row['도서명']
    author = row['저자']
    pub = row['출판사']
    year = row['발행년도']
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(row['ISBN']))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    try:
        if pd.isna(title):
            # 클래스 이름이 'gd_name'인 a 태그의 텍스트를 가져옵니다.
            title = soup.find('a', attrs={'class':'gd_name'}) \
                    .get_text()
    except AttributeError:
        pass

    try:
        if pd.isna(author):
            # 클래스 이름이 'info_auth'인 span 태그 아래 a 태그의 텍스트를 가져옵니다.
            authors = soup.find('span', attrs={'class':'info_auth'}) \
                          .find_all('a')
            author_list = [auth.get_text() for auth in authors]
            author = ','.join(author_list)
    except AttributeError:
        pass

    try:
        if pd.isna(pub):
            # 클래스 이름이 'info_auth'인 span 태그 아래 a 태그의 텍스트를 가져옵니다.
            pub = soup.find('span', attrs={'class':'info_pub'}) \
                      .find('a') \
                      .get_text()
    except AttributeError:
        pass

    try:
        if year == -1:
            # 클래스 이름이 'info_date'인 span 태그 아래 텍스트를 가져옵니다.
            year_str = soup.find('span', attrs={'class':'info_date'}) \
                           .get_text()
            # 정규식으로 찾은 값 중에 첫 번째 것만 사용합니다.
            year = re.findall(r'\d{4}', year_str)[0]
    except AttributeError:
        pass

    return title, author, pub, year

# %%
updated_sample = ns_book5[na_rows].head(2).apply(get_book_info,
    axis=1, result_type ='expand')
updated_sample
# Out:
#                             0                  1    2     3
# 166         이상한 기차  : 한아름 그림책             한아름 지음   창비  2018
# 1121  Khoai Tay lai may bay =  l?i: Mai T?? Ha?m  NaN  2013

# %%
ns_book5_update = ns_book5[na_rows].apply(get_book_info,
     axis=1, result_type ='expand')

ns_book5_update.columns = ['도서명','저자','출판사','발행년도']
ns_book5_update.head()

# %%
ns_book5.update(ns_book5_update)

na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
          | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
print(na_rows.sum())

# %%
ns_book5 = ns_book5.astype({'발행년도': 'int32'})
ns_book6 = ns_book5.dropna(subset=['도서명','저자','출판사'])
ns_book6 = ns_book6[ns_book6['발행년도'] != -1]
ns_book6.head()

# %%
ns_book6.to_csv('ns_book6.csv', index=False)

# %%
#def data_fixing(ns_book4):
    """
    잘못된 값을 수정하거나 NaN 값을 채우는 함수

    :param ns_book4: data_cleaning() 함수에서 전처리된 데이터프레임
    """
    # 도서권수와 대출건수를 int32로 바꿉니다.
    ns_book4 = ns_book4.astype({'도서권수':'int32', '대출건수': 'int32'})
    # NaN인 세트 ISBN을 빈문자열로 바꿉니다.
    set_isbn_na_rows = ns_book4['세트 ISBN'].isna()
    ns_book4.loc[set_isbn_na_rows, '세트 ISBN'] = ''

    # 발행년도 열에서 연도 네 자리를 추출하여 대체합니다. 나머지 발행년도는 -1로 바꿉니다.
    ns_book5 = ns_book4.replace({'발행년도':'.*(\d{4}).*'}, r'\1', regex=True)
    unkown_year = ns_book5['발행년도'].str.contains('\D', na=True)
    ns_book5.loc[unkown_year, '발행년도'] = '-1'

    # 발행년도를 int32로 바꿉니다.
    ns_book5 = ns_book5.astype({'발행년도': 'int32'})
    # 4000년 이상인 경우 2333년을 뺍니다.
    dangun_yy_rows = ns_book5['발행년도'].gt(4000)
    ns_book5.loc[dangun_yy_rows, '발행년도'] = ns_book5.loc[dangun_yy_rows, '발행년도'] - 2333
    # 여전히 4000년 이상인 경우 -1로 바꿉니다.
    dangun_year = ns_book5['발행년도'].gt(4000)
    ns_book5.loc[dangun_year, '발행년도'] = -1
    # 0~1900년 사이의 발행년도는 -1로 바꿉니다.
    old_books = ns_book5['발행년도'].gt(0) & ns_book5['발행년도'].lt(1900)
    ns_book5.loc[old_books, '발행년도'] = -1

    # 도서명, 저자, 출판사가 NaN이거나 발행년도가 -1인 행을 찾습니다.
    na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
              | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
    # 교보문고 도서 상세 페이지에서 누락된 정보를 채웁니다.
    updated_sample = ns_book5[na_rows].apply(get_book_info,
        axis=1, result_type ='expand')
    updated_sample.columns = ['도서명','저자','출판사','발행년도']
    ns_book5.update(updated_sample)

    # 도서명, 저자, 출판사가 NaN이거나 발행년도가 -1인 행을 삭제합니다.
    ns_book6 = ns_book5.dropna(subset=['도서명','저자','출판사'])
    ns_book6 = ns_book6[ns_book6['발행년도'] != -1]

    return ns_book6
